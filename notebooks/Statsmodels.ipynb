# %%
import pandas as pd
from statsmodels.regression.linear_model import OLS
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/dataset_houses_2019-06-28 13:32:31.578004.csv')
df = df[df['area_m2']<1000]

# %%
data = df[['area_m2', 'price']]

# %%
model_fit = ols(formula='price ~ area_m2', data=data).fit()

# %%
model_fit.params
# Out:
# Intercept    81512.189682
# area_m2       1560.971324
# dtype: float64

# %%
area = np.linspace(0, 1000, 1001).reshape(-1, 1)
price = model_fit.predict(df)

# %%
plt.scatter(df.area_m2, price, alpha=0.1)
plt.scatter(df.area_m2, df.price, alpha=0.1)
plt.show()

# %% [markdown]
# ## bse - standard
# mean of estimated parameters

# %%
model_fit.bse
# Out:
# Intercept    1796.438228
# area_m2        10.444810
# dtype: float64

# %% [markdown]
# ## R-squared

# %%
model_fit.rsquared
# Out:
# 0.4880489650322932
