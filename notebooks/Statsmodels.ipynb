# %%
import pandas as pd
from statsmodels.regression.linear_model import OLS
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/ready/num_dataset_houses.csv')
df.columns
# Out:
# Index(['ano_de_construccion', 'banos', 'disposicion', 'dormitorios', 'estado',
#        'garajes', 'gastos_comunes', 'm2_de_la_terraza', 'm2_del_terreno',
#        'm2_edificados', 'price', 'tipo_propiedad', 'vivienda_social', 'zona'],
#       dtype='object')

# %%
data = df[['m2_edificados', 'price']]

# %%
model_fit = ols(formula='price ~ m2_edificados', data=data).fit()

# %%
model_fit.params
# Out:
# Intercept        58155.229049
# m2_edificados     1862.009875
# dtype: float64

# %%
area = np.linspace(0, 1000, 1001).reshape(-1, 1)
price = model_fit.predict(df)

# %%
plt.scatter(df.m2_edificados, price, alpha=0.1)
plt.scatter(df.m2_edificados, df.price, alpha=0.1)
plt.show()

# %% [markdown]
# ## bse - standard
# mean of estimated parameters

# %%
model_fit.bse
# Out:
# Intercept        2200.697287
# m2_edificados      16.615983
# dtype: float64

# %% [markdown]
# ## R-squared

# %%
model_fit.rsquared
# Out:
# 0.5268894279335737
